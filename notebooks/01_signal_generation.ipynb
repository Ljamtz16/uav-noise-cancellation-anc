# %% [markdown]
# # 01 - UAV Signal Generation
# Genera una señal sintética de UAV con BPF + armónicos + ruido.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %%
from src.signal.generate_signal import generate_uav_signal
from src.utils.plotting import plot_time_series

fs = 8000
t, x, f_bpf = generate_uav_signal(fs=fs, duration=2, rpm=6000, n_blades=2)
print(f'BPF estimada por modelo: {f_bpf:.2f} Hz')
plot_time_series(t[:2000], x[:2000], title='UAV signal (primeros 2000 samples)')
